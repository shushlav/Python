# %% [markdown]
# # Feature Selection with Categorical Data

# %% [markdown]
# ## The two most commonly used feature selection methods for categorical input data when the target variable is also categorical (e.g. classification predictive modeling) are the chi-squared statistic and the mutual information statistic.

# %% [markdown]
# https://machinelearningmastery.com/feature-selection-with-categorical-data/

# %%
import pandas as pd 
# load the dataset as a pandas DataFrame
data = pd.read_csv('D:\\Python\\Data Science\\scikit-learn-videos-master\\breast_cancer_data1980.csv', header=None)
# retrieve numpy array
dataset = data.values   # # retrieve numpy array

print(dataset)
data.head(50)
# Out:
# [["'40-49'" "'premeno'" "'15-19'" ... "'left_up'" "'no'"
#   "'recurrence-events'"]
#  ["'50-59'" "'ge40'" "'15-19'" ... "'central'" "'no'"
#   "'no-recurrence-events'"]
#  ["'50-59'" "'ge40'" "'35-39'" ... "'left_low'" "'no'"
#   "'recurrence-events'"]
#  ...
#  ["'30-39'" "'premeno'" "'30-34'" ... "'right_up'" "'no'"
#   "'no-recurrence-events'"]
#  ["'50-59'" "'premeno'" "'15-19'" ... "'left_low'" "'no'"
#   "'no-recurrence-events'"]
#  ["'50-59'" "'ge40'" "'40-44'" ... "'right_up'" "'no'"
#   "'no-recurrence-events'"]]
#           0          1        2        3      4    5        6            7  \
# 0   '40-49'  'premeno'  '15-19'    '0-2'  'yes'  '3'  'right'    'left_up'
# 1   '50-59'     'ge40'  '15-19'    '0-2'   'no'  '1'  'right'    'central'
# 2   '50-59'     'ge40'  '35-39'    '0-2'   'no'  '2'   'left'   'left_low'
# 3   '40-49'  'premeno'  '35-39'    '0-2'  'yes'  '3'  'right'   'left_low'
# 4   '40-49'  'premeno'  '30-34'    '3-5'  'yes'  '2'   'left'   'right_up'
# 5   '50-59'  'premeno'  '25-29'    '3-5'   'no'  '2'  'right'    'left_up'
# 6   '50-59'     'ge40'  '40-44'    '0-2'   'no'  '3'   'left'    'left_up'
# 7   '40-49'  'premeno'  '10-14'    '0-2'   'no'  '2'   'left'    'left_up'
# 8   '40-49'  'premeno'    '0-4'    '0-2'   'no'  '2'  'right'  'right_low'
# 9   '40-49'     'ge40'  '40-44'  '15-17'  'yes'  '2'  'right'    'left_up'
# 10  '50-59'  'premeno'  '25-29'    '0-2'   'no'  '2'   'left'   'left_low'
# 11  '60-69'     'ge40'  '15-19'    '0-2'   'no'  '2'  'right'    'left_up'
# 12  '50-59'     'ge40'  '30-34'    '0-2'   'no'  '1'  'right'    'central'
# 13  '50-59'     'ge40'  '25-29'    '0-2'   'no'  '2'  'right'    'left_up'
# 14  '40-49'  'premeno'  '25-29'    '0-2'   'no'  '2'   'left'   'left_low'
# 15  '30-39'  'premeno'  '20-24'    '0-2'   'no'  '3'   'left'    'central'
# 16  '50-59'  'premeno'  '10-14'    '3-5'   'no'  '1'  'right'    'left_up'
# 17  '60-69'     'ge40'  '15-19'    '0-2'   'no'  '2'  'right'    'left_up'
# 18  '50-59'  'premeno'  '40-44'    '0-2'   'no'  '2'   'left'    'left_up'
# 19  '50-59'     'ge40'  '20-24'    '0-2'   'no'  '3'   'left'    'left_up'
# 20  '50-59'     'lt40'  '20-24'    '0-2'    NaN  '1'   'left'   'left_low'
# 21  '60-69'     'ge40'  '40-44'    '3-5'   'no'  '2'  'right'    'left_up'
# 22  '50-59'     'ge40'  '15-19'    '0-2'   'no'  '2'  'right'   'left_low'
# 23  '40-49'  'premeno'  '10-14'    '0-2'   'no'  '1'  'right'    'left_up'
# 24  '30-39'  'premeno'  '15-19'    '6-8'  'yes'  '3'   'left'   'left_low'
# 25  '50-59'     'ge40'  '20-24'    '3-5'  'yes'  '2'  'right'    'left_up'
# 26  '50-59'     'ge40'  '10-14'    '0-2'   'no'  '2'  'right'   'left_low'
# 27  '40-49'  'premeno'  '10-14'    '0-2'   'no'  '1'  'right'    'left_up'
# 28  '60-69'     'ge40'  '30-34'    '3-5'  'yes'  '3'   'left'   'left_low'
# 29  '40-49'  'premeno'  '15-19'  '15-17'  'yes'  '3'   'left'   'left_low'
# 30  '60-69'     'ge40'  '30-34'    '0-2'   'no'  '3'  'right'    'central'
# 31  '60-69'     'ge40'  '25-29'    '3-5'    NaN  '1'  'right'   'left_low'
# 32  '50-59'     'ge40'  '25-29'    '0-2'   'no'  '3'   'left'   'right_up'
# 33  '50-59'     'ge40'  '20-24'    '0-2'   'no'  '3'  'right'    'left_up'
# 34  '40-49'  'premeno'  '30-34'    '0-2'   'no'  '1'   'left'   'left_low'
# 35  '30-39'  'premeno'  '15-19'    '0-2'   'no'  '1'   'left'   'left_low'
# 36  '40-49'  'premeno'  '10-14'    '0-2'   'no'  '2'  'right'    'left_up'
# 37  '60-69'     'ge40'  '45-49'    '6-8'  'yes'  '3'   'left'    'central'
# 38  '40-49'     'ge40'  '20-24'    '0-2'   'no'  '3'   'left'   'left_low'
# 39  '40-49'  'premeno'  '10-14'    '0-2'   'no'  '1'  'right'  'right_low'
# 40  '30-39'  'premeno'  '35-39'    '0-2'   'no'  '3'   'left'   'left_low'
# 41  '40-49'  'premeno'  '35-39'   '9-11'  'yes'  '2'  'right'   'right_up'
# 42  '60-69'     'ge40'  '25-29'    '0-2'   'no'  '2'  'right'   'left_low'
# 43  '50-59'     'ge40'  '20-24'    '3-5'  'yes'  '3'  'right'   'right_up'
# 44  '30-39'  'premeno'  '15-19'    '0-2'   'no'  '1'   'left'   'left_low'
# 45  '50-59'  'premeno'  '30-34'    '0-2'   'no'  '3'   'left'   'right_up'
# 46  '60-69'     'ge40'  '10-14'    '0-2'   'no'  '2'  'right'    'left_up'
# 47  '40-49'  'premeno'  '35-39'    '0-2'  'yes'  '3'  'right'    'left_up'
# 48  '50-59'  'premeno'  '50-54'    '0-2'  'yes'  '2'  'right'    'left_up'
# 49  '50-59'     'ge40'  '40-44'    '0-2'   'no'  '3'  'right'    'left_up'
#
#         8                       9
# 0    'no'     'recurrence-events'
# 1    'no'  'no-recurrence-events'
# 2    'no'     'recurrence-events'
# 3   'yes'  'no-recurrence-events'
# 4    'no'     'recurrence-events'
# 5   'yes'  'no-recurrence-events'
# 6    'no'  'no-recurrence-events'
# 7    'no'  'no-recurrence-events'
# 8    'no'  'no-recurrence-events'
# 9   'yes'  'no-recurrence-events'
# 10   'no'  'no-recurrence-events'
# 11   'no'  'no-recurrence-events'
# 12   'no'  'no-recurrence-events'
# 13   'no'  'no-recurrence-events'
# 14  'yes'     'recurrence-events'
# 15   'no'  'no-recurrence-events'
# 16   'no'  'no-recurrence-events'
# 17   'no'  'no-recurrence-events'
# 18   'no'  'no-recurrence-events'
# 19   'no'  'no-recurrence-events'
# 20   'no'     'recurrence-events'
# 21  'yes'  'no-recurrence-events'
# 22   'no'  'no-recurrence-events'
# 23   'no'  'no-recurrence-events'
# 24  'yes'     'recurrence-events'
# 25   'no'  'no-recurrence-events'
# 26   'no'  'no-recurrence-events'
# 27   'no'  'no-recurrence-events'
# 28   'no'  'no-recurrence-events'
# 29   'no'     'recurrence-events'
# 30   'no'     'recurrence-events'
# 31  'yes'  'no-recurrence-events'
# 32   'no'  'no-recurrence-events'
# 33   'no'  'no-recurrence-events'
# 34  'yes'     'recurrence-events'
# 35   'no'  'no-recurrence-events'
# 36   'no'  'no-recurrence-events'
# 37   'no'  'no-recurrence-events'
# 38   'no'  'no-recurrence-events'
# 39   'no'  'no-recurrence-events'
# 40   'no'     'recurrence-events'
# 41  'yes'  'no-recurrence-events'
# 42   'no'  'no-recurrence-events'
# 43   'no'     'recurrence-events'
# 44   'no'  'no-recurrence-events'
# 45   'no'     'recurrence-events'
# 46  'yes'  'no-recurrence-events'
# 47  'yes'  'no-recurrence-events'
# 48  'yes'  'no-recurrence-events'
# 49   'no'  'no-recurrence-events'

# %%
# split into input (X) and output (y) variables
X = dataset[:, :-1]
y = dataset[:,-1]

# %% [markdown]
# Finally, we can force all fields in the input data to be string, just in case Pandas tried to map some automatically to numbers (it does try).

# %%
# format all fields as string
X = X.astype(str)

# %%
from sklearn.model_selection import train_test_split

# split the data into training and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# summarize
print('Train', X_train.shape, y_train.shape)
print('Test', X_test.shape, y_test.shape)
# Out:
# Train (190, 9) (190,)
# Test (95, 9) (95,)

# %% [markdown]
# ### We can use the OrdinalEncoder() from scikit-learn to encode each variable to integers. This is a flexible class and does allow the order of the categories to be specified as arguments if any such order is known.
# The best practice when encoding variables is to fit the encoding on the training dataset, then apply it to the train and test datasets.

# %%
from sklearn.preprocessing import OrdinalEncoder
# EXAMPLE FOR ENCODE:
enc = OrdinalEncoder()
X = [['Male', 1], ['Female', 3], ['Female', 2]]
enc.fit(X)
print(enc.categories_)
enc.transform([['Female', 3], ['Male', 1]])
# Out:
# [array(['Female', 'Male'], dtype=object), array([1, 2, 3], dtype=object)]
# array([[0., 2.],
#        [1., 0.]])

# %%
from sklearn.preprocessing import OrdinalEncoder   # יש חשיבות וסדר לנתונים (לדוגמה שנות לימוד)
# prepare input data
def prepare_inputs(X_train, X_test):
	oe = OrdinalEncoder()     # instanciate OrdinalEncoder to Encode categorical features as an integer array.
	oe.fit(X_train)
	X_train_enc = oe.transform(X_train)
	X_test_enc = oe.transform(X_test)
	return X_train_enc, X_test_enc

# %% [markdown]
# ## prepare the target variable - map the two class labels to 0 and 1 using LabelEncoder
# This is a type of ordinal encoding, and scikit-learn provides the LabelEncoder class specifically designed for this purpose. We could just as easily use the OrdinalEncoder and achieve the same result, although the LabelEncoder is designed for encoding a single variable

# %%
import numpy as np
np.unique(X_train[: ,2], return_counts=True)
# Out:
# (array(["'0-4'", "'10-14'", "'15-19'", "'20-24'", "'25-29'", "'30-34'",
#         "'35-39'", "'40-44'", "'45-49'", "'5-9'", "'50-54'"], dtype='<U11'),
#  array([ 6, 23, 20, 26, 37, 46, 10, 11,  3,  4,  4], dtype=int64))

# %%
ordi = ["'0-4'", "'5-9'", "'10-14'", "'15-19'", "'20-24'", "'25-29'", "'30-34'",
        "'35-39'", "'40-44'", "'45-49'", "'50-54'"]                                    # assigning in the correct order

# %%
# check where we need to order the list before LabelEncoder
for a in range (0, 9):
    print(a, ":", np.unique(X_train[: ,a]))
# Out:
# 0 : ["'20-29'" "'30-39'" "'40-49'" "'50-59'" "'60-69'" "'70-79'"]
# 1 : ["'ge40'" "'lt40'" "'premeno'"]
# 2 : ["'0-4'" "'10-14'" "'15-19'" "'20-24'" "'25-29'" "'30-34'" "'35-39'"
#  "'40-44'" "'45-49'" "'5-9'" "'50-54'"]
# 3 : ["'0-2'" "'12-14'" "'15-17'" "'3-5'" "'6-8'" "'9-11'"]
# 4 : ["'no'" "'yes'" 'nan']
# 5 : ["'1'" "'2'" "'3'"]
# 6 : ["'left'" "'right'"]
# 7 : ["'central'" "'left_low'" "'left_up'" "'right_low'" "'right_up'" 'nan']
# 8 : ["'no'" "'yes'"]

# %%
from sklearn.preprocessing import LabelEncoder
# prepare target
def prepare_targets(y_train, y_test):
	le = LabelEncoder()
	le.fit(y_train)
	y_train_enc = le.transform(y_train)
	y_test_enc = le.transform(y_test)
	return y_train_enc, y_test_enc

# %%
ordi = OrdinalEncoder(categories=[2])
ordi.fit(X-train[[]])

# %%
np.unique(X_train[: ,3])
# Out:
# array(["'0-2'", "'12-14'", "'15-17'", "'3-5'", "'6-8'", "'9-11'"],
#       dtype='<U11')

# %%
np.unique(24-26, return_index=True)
# Out:
# (array([-2]), array([0], dtype=int64))

# %%
# call these functions to prepare our data:
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-38a0a2575868> in <module>
#       1 # call these functions to prepare our data:
#       2 # prepare input data
# ----> 3 X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
#       4 # prepare output data
#       5 y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
#
# <ipython-input-20-08477179cd62> in prepare_inputs(X_train, X_test)
#       4         oe.fit(X_train)
#       5         X_train_enc = oe.transform(X_train)
# ----> 6         X_test_enc = oe.transform(X_test)
#       7         return X_train_enc, X_test_enc
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_encoders.py in transform(self, X)
#     803             Transformed input.
#     804         """
# --> 805         X_int, X_mask = self._transform(X, handle_unknown=self.handle_unknown)
#     806         X_trans = X_int.astype(self.dtype, copy=False)
#     807
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\preprocessing\_encoders.py in _transform(self, X, handle_unknown, force_all_finite)
#     134                     msg = ("Found unknown categories {0} in column {1}"
#     135                            " during transform".format(diff, i))
# --> 136                     raise ValueError(msg)
#     137                 else:
#     138                     # Set the problematic rows to an acceptable value and
#
# ValueError: Found unknown categories ["'24-26'"] in column 3 during transform
